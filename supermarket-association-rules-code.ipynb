# %% [markdown]
# # Association Rule Mining - Market Basket Analysis
# ### Raul Almuzara

# %% [markdown]
# ------------------------

# %% [markdown]
# We find association rules with a support of at least $0.2$ and a confidence of at least $0.7$ based on the list of transactions from *supermarket.arff*

# %% [markdown]
# --------------------------

# %% [markdown]
# **Basic definitions in association rule mining:**
#
# We consider rules *R* of the form *IF A THEN B* where *A* and *B* are sets of items.
#
# - The **support** of a set of items is the number of transactions which contain all the items of the set divided by the total number of transactions in the dataset.
#
# - The **support** of an association rule is the number of transactions which contain all the items involved in the rule (in A and B) divided by the total number of transactions in the dataset.
#
# - The **confidence** of an association rule is the support of the union of A and B divided by the support of A.
#
# $$\text{conf}(R) = \frac{\text{supp}(A\cup B)}{\text{supp}(A)}$$
#
# - The **lift** of an association rule is the support of the union of A and B divided by the product of the support of *A* and the support of *B*.
#
# $$\text{lift}(R) = \frac{\text{supp}(A\cup B)}{\text{supp}(A)\cdot\text{supp}(B)}$$

# %% [markdown]
# --------------------------

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
from scipy.io import arff
import apyori
from apyori import apriori

# %% [markdown]
# ### Load data

# %%
data = arff.loadarff('supermarket.arff')
df = pd.DataFrame(data[0])

# %%
df
# Out:
#      department1 department2 department3 department4 department5 department6  \
# 0           b'?'        b'?'        b'?'        b'?'        b'?'        b'?'
# 1           b't'        b'?'        b'?'        b'?'        b'?'        b'?'
# 2           b'?'        b'?'        b'?'        b'?'        b'?'        b'?'
# 3           b't'        b'?'        b'?'        b'?'        b'?'        b'?'
# 4           b'?'        b'?'        b'?'        b'?'        b'?'        b'?'
# ...          ...         ...         ...         ...         ...         ...
# 4622        b'?'        b'?'        b'?'        b'?'        b'?'        b'?'
# 4623        b'?'        b'?'        b'?'        b't'        b'?'        b'?'
# 4624        b'?'        b'?'        b'?'        b'?'        b'?'        b'?'
# 4625        b'?'        b'?'        b'?'        b'?'        b'?'        b'?'
# 4626        b't'        b'?'        b'?'        b'?'        b'?'        b'?'
#
#      department7 department8 department9 grocery misc  ... department208  \
# 0           b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 1           b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 2           b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 3           b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 4           b'?'        b'?'        b'?'         b'?'  ...          b'?'
# ...          ...         ...         ...          ...  ...           ...
# 4622        b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 4623        b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 4624        b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 4625        b'?'        b'?'        b'?'         b'?'  ...          b'?'
# 4626        b'?'        b'?'        b'?'         b'?'  ...          b'?'
#
#      department209 department210 department211 department212 department213  \
# 0             b'?'          b'?'          b'?'          b'?'          b'?'
# 1             b'?'          b'?'          b'?'          b'?'          b'?'
# 2             b'?'          b'?'          b'?'          b'?'          b'?'
# 3             b'?'          b'?'          b'?'          b'?'          b'?'
# 4             b'?'          b'?'          b'?'          b'?'          b'?'
# ...            ...           ...           ...           ...           ...
# 4622          b'?'          b'?'          b'?'          b'?'          b'?'
# 4623          b'?'          b'?'          b'?'          b'?'          b'?'
# 4624          b'?'          b'?'          b'?'          b'?'          b'?'
# 4625          b'?'          b'?'          b'?'          b'?'          b'?'
# 4626          b'?'          b'?'          b'?'          b'?'          b'?'
#
#      department214 department215 department216    total
# 0             b'?'          b'?'          b'?'  b'high'
# 1             b'?'          b'?'          b'?'   b'low'
# 2             b'?'          b'?'          b'?'   b'low'
# 3             b'?'          b'?'          b'?'   b'low'
# 4             b'?'          b'?'          b'?'   b'low'
# ...            ...           ...           ...      ...
# 4622          b'?'          b'?'          b'?'   b'low'
# 4623          b'?'          b'?'          b'?'  b'high'
# 4624          b'?'          b'?'          b'?'   b'low'
# 4625          b'?'          b'?'          b'?'   b'low'
# 4626          b'?'          b'?'          b'?'  b'high'
#
# [4627 rows x 217 columns]

# %% [markdown]
# As we can see, there are 4627 transactions and 217 attributes. The first 216 attributes indicate if a specific product has been purchased (*t*) or has not been purchased (*?*). The 217th attribute (*total*) is related to the total cost of the transaction and we can drop it because we are only interested in the lists of products purchased.

# %%
df = df.drop(['total'],axis=1)

# %% [markdown]
# Full list of attributes of interest indicating the different products available:

# %%
attributes = list(df.columns)

# %%
attributes
# Out:
# ['department1',
#  'department2',
#  'department3',
#  'department4',
#  'department5',
#  'department6',
#  'department7',
#  'department8',
#  'department9',
#  'grocery misc',
#  'department11',
#  'baby needs',
#  'bread and cake',
#  'baking needs',
#  'coupons',
#  'juice-sat-cord-ms',
#  'tea',
#  'biscuits',
#  'canned fish-meat',
#  'canned fruit',
#  'canned vegetables',
#  'breakfast food',
#  'cigs-tobacco pkts',
#  'cigarette cartons',
#  'cleaners-polishers',
#  'coffee',
#  'sauces-gravy-pkle',
#  'confectionary',
#  'puddings-deserts',
#  'dishcloths-scour',
#  'deod-disinfectant',
#  'frozen foods',
#  'razor blades',
#  'fuels-garden aids',
#  'spices',
#  'jams-spreads',
#  'insecticides',
#  'pet foods',
#  'laundry needs',
#  'party snack foods',
#  'tissues-paper prd',
#  'wrapping',
#  'dried vegetables',
#  'pkt-canned soup',
#  'soft drinks',
#  'health food other',
#  'beverages hot',
#  'health&beauty misc',
#  'deodorants-soap',
#  'mens toiletries',
#  'medicines',
#  'haircare',
#  'dental needs',
#  'lotions-creams',
#  'sanitary pads',
#  'cough-cold-pain',
#  'department57',
#  'meat misc',
#  'cheese',
#  'chickens',
#  'milk-cream',
#  'cold-meats',
#  'deli gourmet',
#  'margarine',
#  'salads',
#  'small goods',
#  'dairy foods',
#  'fruit drinks',
#  'delicatessen misc',
#  'department70',
#  'beef',
#  'hogget',
#  'lamb',
#  'pet food',
#  'pork',
#  'poultry',
#  'veal',
#  'gourmet meat',
#  'department79',
#  'department80',
#  'department81',
#  'produce misc',
#  'fruit',
#  'plants',
#  'potatoes',
#  'vegetables',
#  'flowers',
#  'department88',
#  'department89',
#  'variety misc',
#  'brushware',
#  'electrical',
#  'haberdashery',
#  'kitchen',
#  'manchester',
#  'pantyhose',
#  'plasticware',
#  'department98',
#  'stationary',
#  'department100',
#  'department101',
#  'department102',
#  'prepared meals',
#  'preserving needs',
#  'condiments',
#  'cooking oils',
#  'department107',
#  'department108',
#  'department109',
#  'department110',
#  'department111',
#  'department112',
#  'department113',
#  'department114',
#  'health food bulk',
#  'department116',
#  'department117',
#  'department118',
#  'department119',
#  'department120',
#  'bake off products',
#  'department122',
#  'department123',
#  'department124',
#  'department125',
#  'department126',
#  'department127',
#  'department128',
#  'department129',
#  'department130',
#  'small goods2',
#  'offal',
#  'mutton',
#  'trim pork',
#  'trim lamb',
#  'imported cheese',
#  'department137',
#  'department138',
#  'department139',
#  'department140',
#  'department141',
#  'department142',
#  'department143',
#  'department144',
#  'department145',
#  'department146',
#  'department147',
#  'department148',
#  'department149',
#  'department150',
#  'department151',
#  'department152',
#  'department153',
#  'department154',
#  'department155',
#  'department156',
#  'department157',
#  'department158',
#  'department159',
#  'department160',
#  'department161',
#  'department162',
#  'department163',
#  'department164',
#  'department165',
#  'department166',
#  'department167',
#  'department168',
#  'department169',
#  'department170',
#  'department171',
#  'department172',
#  'department173',
#  'department174',
#  'department175',
#  'department176',
#  'department177',
#  'department178',
#  'department179',
#  'casks white wine',
#  'casks red wine',
#  '750ml white nz',
#  '750ml red nz',
#  '750ml white imp',
#  '750ml red imp',
#  'sparkling nz',
#  'sparkling imp',
#  'brew kits/accesry',
#  'department189',
#  'port and sherry',
#  'ctrled label wine',
#  'department192',
#  'department193',
#  'department194',
#  'department195',
#  'department196',
#  'department197',
#  'department198',
#  'department199',
#  'non host support',
#  'department201',
#  'department202',
#  'department203',
#  'department204',
#  'department205',
#  'department206',
#  'department207',
#  'department208',
#  'department209',
#  'department210',
#  'department211',
#  'department212',
#  'department213',
#  'department214',
#  'department215',
#  'department216']

# %% [markdown]
# Since the data in the original *.arff* file seems to be encoded in the *bytes* format, we transform the data into strings and into a numpy matrix for easier handling.

# %%
sales = df.to_numpy().astype(str)

# %%
sales
# Out:
# array([['?', '?', '?', ..., '?', '?', '?'],
#        ['t', '?', '?', ..., '?', '?', '?'],
#        ['?', '?', '?', ..., '?', '?', '?'],
#        ...,
#        ['?', '?', '?', ..., '?', '?', '?'],
#        ['?', '?', '?', ..., '?', '?', '?'],
#        ['t', '?', '?', ..., '?', '?', '?']], dtype='<U1')

# %% [markdown]
# Now, we want to build lists with the specific attributes involved in each individual transaction (those with the *t* symbol).

# %%
transactions = [ [] for _ in range(df.shape[0]) ]  #Empty lists to be filled with the specific products purchased.

#We iterate over every element in the sales matrix and, if a product belongs to a transaction, we save it.
for i in range(df.shape[0]):
    for j in range(df.shape[1]):
        if sales[i,j] == "t":
            transactions[i].append(attributes[j])

# %%
transactions
# Out:
# [['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   'frozen foods',
#   'razor blades',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'mens toiletries',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'fruit',
#   'vegetables',
#   'department122',
#   '750ml white nz'],
#  ['department1',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'haircare',
#   'milk-cream',
#   'fruit',
#   'vegetables'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'wrapping',
#   'health food other',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'mens toiletries',
#   'cheese',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'stationary',
#   'prepared meals',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'meat misc',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'potatoes',
#   'vegetables',
#   'condiments',
#   'small goods2'],
#  ['department3',
#   'department7',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'confectionary',
#   'frozen foods',
#   'spices',
#   'party snack foods',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'bake off products',
#   'department122',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'tissues-paper prd',
#   'soft drinks',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'electrical'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'sanitary pads',
#   'milk-cream',
#   'fruit',
#   'vegetables'],
#  ['department1',
#   'department3',
#   'fruit',
#   'stationary',
#   'bake off products',
#   'department122',
#   'department130',
#   '750ml red imp'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'wrapping',
#   'dental needs',
#   'milk-cream',
#   'beef',
#   'fruit',
#   'vegetables',
#   'electrical',
#   'department130',
#   'department137',
#   'sparkling nz'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'coffee',
#   'dishcloths-scour',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'haircare',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'pork',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'department122',
#   'department130',
#   'small goods2',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'puddings-deserts',
#   'jams-spreads',
#   'laundry needs',
#   'beverages hot',
#   'deodorants-soap',
#   'lotions-creams',
#   'cough-cold-pain',
#   'cheese',
#   'margarine',
#   'beef',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'department137'],
#  ['department1',
#   'department2',
#   'grocery misc',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'party snack foods',
#   'pkt-canned soup',
#   'margarine',
#   'dairy foods'],
#  ['baking needs',
#   'puddings-deserts',
#   'jams-spreads',
#   'party snack foods',
#   'haircare',
#   'lotions-creams',
#   'produce misc',
#   'fruit',
#   'vegetables',
#   'prepared meals'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'pet foods',
#   'party snack foods',
#   'cheese',
#   'milk-cream',
#   'deli gourmet',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'variety misc',
#   'kitchen',
#   'stationary',
#   'department130',
#   'imported cheese'],
#  ['department1',
#   'department5',
#   'department7',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'dishcloths-scour',
#   'frozen foods',
#   'fuels-garden aids',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'pkt-canned soup',
#   'soft drinks',
#   'haircare',
#   'dental needs',
#   'margarine',
#   'small goods',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'prepared meals',
#   'bake off products',
#   'department122',
#   'small goods2'],
#  ['juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'deod-disinfectant',
#   'frozen foods',
#   'party snack foods',
#   'cheese',
#   'cold-meats',
#   'margarine',
#   'beef',
#   'variety misc',
#   'stationary'],
#  ['department1',
#   'department3',
#   'bread and cake',
#   'biscuits',
#   'fruit',
#   'vegetables',
#   'casks white wine',
#   'sparkling nz'],
#  ['department1',
#   'grocery misc',
#   'baby needs',
#   'baking needs',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'laundry needs',
#   'party snack foods',
#   'wrapping',
#   'beverages hot',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'condiments',
#   'bake off products',
#   'department122'],
#  ['department1',
#   'biscuits',
#   'canned fish-meat',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'party snack foods',
#   'fruit',
#   'prepared meals',
#   'cooking oils'],
#  ['department2',
#   'department5',
#   'grocery misc',
#   'bread and cake',
#   'biscuits',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'pet foods',
#   'cheese',
#   'milk-cream',
#   'deli gourmet',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'pork',
#   'produce misc',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'department122',
#   'department130',
#   'offal'],
#  ['department1',
#   'department2',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'pet food',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'electrical',
#   'manchester',
#   'plasticware',
#   'stationary',
#   'prepared meals',
#   'cooking oils',
#   'bake off products',
#   'department122',
#   'department130',
#   'small goods2',
#   'department137'],
#  ['baking needs',
#   'biscuits',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'pork',
#   'poultry',
#   'department79',
#   'fruit',
#   'vegetables',
#   'small goods2',
#   'department137'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'soft drinks',
#   'mens toiletries',
#   'lotions-creams',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'vegetables'],
#  ['bread and cake',
#   'baking needs',
#   'tea',
#   'sauces-gravy-pkle',
#   'laundry needs',
#   'tissues-paper prd',
#   'beverages hot',
#   'milk-cream',
#   'beef',
#   'lamb',
#   'fruit',
#   'department122',
#   'small goods2'],
#  ['department4',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'frozen foods',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'milk-cream',
#   'cold-meats',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'electrical',
#   'department122'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'canned vegetables',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'frozen foods',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'prepared meals',
#   'small goods2',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'deod-disinfectant',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'beverages hot',
#   'deodorants-soap',
#   'mens toiletries',
#   'haircare',
#   'dental needs',
#   'cheese',
#   'small goods',
#   'dairy foods',
#   'pet food',
#   'fruit',
#   'stationary',
#   'department122',
#   'small goods2',
#   'department137'],
#  ['baking needs',
#   'tea',
#   'confectionary',
#   'deod-disinfectant',
#   'frozen foods',
#   'fuels-garden aids',
#   'party snack foods',
#   'cheese',
#   'dairy foods',
#   'department79',
#   'variety misc',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'coffee',
#   'confectionary',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'dental needs',
#   'milk-cream'],
#  ['juice-sat-cord-ms',
#   'tea',
#   'canned fish-meat',
#   'coffee',
#   'jams-spreads',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'fruit',
#   'cooking oils',
#   'non host support'],
#  ['bread and cake',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'frozen foods',
#   'party snack foods',
#   'wrapping',
#   'lotions-creams',
#   'cheese',
#   'fruit',
#   'kitchen',
#   'bake off products'],
#  ['bread and cake',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'cleaners-polishers',
#   'frozen foods',
#   'party snack foods',
#   'soft drinks',
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   'haberdashery',
#   'kitchen',
#   'prepared meals',
#   'port and sherry'],
#  ['department1',
#   'department2',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'confectionary',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'haircare',
#   'cheese',
#   'margarine',
#   'beef',
#   'lamb',
#   'pork',
#   'fruit',
#   'vegetables',
#   'plasticware',
#   'small goods2',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'biscuits',
#   'jams-spreads',
#   'party snack foods',
#   'haircare',
#   'milk-cream',
#   'delicatessen misc',
#   'department79',
#   'fruit',
#   'vegetables',
#   'department122',
#   'department130',
#   'small goods2',
#   'department211'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'spices',
#   'jams-spreads',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'stationary',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'spices',
#   'jams-spreads',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'soft drinks',
#   'beverages hot',
#   'deodorants-soap',
#   'haircare',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'deli gourmet',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'stationary',
#   'prepared meals',
#   'department122',
#   'department137'],
#  ['bread and cake',
#   'canned fish-meat',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'coffee',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'frozen foods',
#   'spices',
#   'laundry needs',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'condiments',
#   'department137'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'wrapping',
#   'soft drinks',
#   'health&beauty misc',
#   'deodorants-soap',
#   'mens toiletries',
#   'haircare',
#   'dental needs',
#   'cough-cold-pain',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'department122'],
#  ['department1',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   'stationary',
#   'cooking oils',
#   'bake off products',
#   'department122'],
#  ['bread and cake',
#   'cigs-tobacco pkts',
#   'frozen foods',
#   'wrapping',
#   'dental needs',
#   'milk-cream',
#   'variety misc',
#   'prepared meals'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'deod-disinfectant',
#   'frozen foods',
#   'fuels-garden aids',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'sanitary pads',
#   'cheese',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'electrical',
#   'plasticware',
#   'stationary',
#   'prepared meals'],
#  ['baking needs',
#   'biscuits',
#   'canned vegetables',
#   'coffee',
#   'confectionary',
#   'deod-disinfectant',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'lotions-creams',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'beef',
#   'lamb',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'electrical'],
#  ['department9',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'sauces-gravy-pkle',
#   'spices',
#   'jams-spreads',
#   'soft drinks',
#   'haircare',
#   'cheese',
#   'margarine',
#   'small goods',
#   'produce misc',
#   'vegetables',
#   'electrical',
#   'prepared meals',
#   'condiments',
#   'small goods2',
#   'department137',
#   'department211'],
#  ['baking needs',
#   'biscuits',
#   'confectionary',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'potatoes',
#   'kitchen',
#   'stationary',
#   'department123',
#   'department137'],
#  ['department5',
#   'bread and cake',
#   'milk-cream',
#   'variety misc',
#   'kitchen',
#   'department124'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'confectionary',
#   'frozen foods',
#   'fuels-garden aids',
#   'spices',
#   'party snack foods',
#   'wrapping',
#   'dried vegetables',
#   'medicines',
#   'lotions-creams',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'fruit'],
#  ['baking needs',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'tissues-paper prd',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'poultry',
#   'fruit',
#   'electrical',
#   'stationary',
#   'condiments',
#   'port and sherry'],
#  ['baking needs',
#   'juice-sat-cord-ms',
#   'breakfast food',
#   'spices',
#   'wrapping',
#   'sanitary pads',
#   'cheese',
#   'fruit',
#   'variety misc',
#   'kitchen',
#   'cooking oils'],
#  ['baby needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'razor blades',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'mens toiletries',
#   'cheese',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'pork',
#   'potatoes'],
#  ['department1',
#   'grocery misc',
#   'cigs-tobacco pkts',
#   'party snack foods',
#   'pork',
#   'poultry',
#   'stationary'],
#  ['baking needs',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'tissues-paper prd',
#   'health food other',
#   'deodorants-soap',
#   'dental needs',
#   'cough-cold-pain',
#   'cheese',
#   'pet food',
#   'potatoes',
#   'vegetables',
#   'department137'],
#  ['department2',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'cheese',
#   'milk-cream',
#   'dairy foods',
#   'fruit',
#   'haberdashery',
#   'stationary',
#   'department122',
#   'department137'],
#  ['bread and cake',
#   'biscuits',
#   'cigs-tobacco pkts',
#   'insecticides',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'bake off products',
#   'department122'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'canned fish-meat',
#   'canned vegetables',
#   'coffee',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'lamb',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'plasticware',
#   'stationary',
#   'cooking oils'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'puddings-deserts',
#   'wrapping',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'beef',
#   'potatoes',
#   'vegetables',
#   'cooking oils',
#   'department122'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'dental needs',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'small goods2',
#   'trim pork'],
#  ['bread and cake',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'spices',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'health food other',
#   'beverages hot',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'department130'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'cigarette cartons',
#   'cleaners-polishers',
#   'frozen foods',
#   'fuels-garden aids',
#   'jams-spreads',
#   'tissues-paper prd',
#   'fruit',
#   'vegetables'],
#  ['grocery misc',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'party snack foods',
#   'soft drinks',
#   'deodorants-soap',
#   'cheese',
#   'beef',
#   'fruit',
#   'prepared meals',
#   'department137'],
#  ['bread and cake',
#   'biscuits',
#   'breakfast food',
#   'cleaners-polishers',
#   'deod-disinfectant',
#   'pet foods',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'haircare',
#   'milk-cream',
#   'poultry',
#   'vegetables'],
#  ['department1',
#   'baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'frozen foods',
#   'spices',
#   'jams-spreads',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'cheese',
#   'margarine',
#   'small goods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'variety misc',
#   'imported cheese'],
#  ['juice-sat-cord-ms',
#   'breakfast food',
#   'cleaners-polishers',
#   'confectionary',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'medicines',
#   'dental needs',
#   'cheese',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'produce misc',
#   'fruit',
#   'vegetables'],
#  ['bread and cake',
#   'baking needs',
#   'canned fish-meat',
#   'canned fruit',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'beverages hot',
#   'meat misc',
#   'cheese',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'bake off products'],
#  ['grocery misc',
#   'bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'cigs-tobacco pkts',
#   'coffee',
#   'confectionary',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'wrapping',
#   'soft drinks',
#   'beverages hot',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'fruit',
#   'plants',
#   'stationary',
#   'bake off products',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'dishcloths-scour',
#   'frozen foods',
#   'spices',
#   'laundry needs',
#   'health food other',
#   'beverages hot',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'bake off products',
#   'department137'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'party snack foods',
#   'deodorants-soap',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'poultry',
#   'department79',
#   'fruit',
#   'vegetables',
#   'variety misc',
#   'kitchen',
#   'stationary',
#   'prepared meals',
#   'cooking oils',
#   'bake off products',
#   'small goods2',
#   'department137',
#   'casks white wine'],
#  ['department1',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'frozen foods',
#   'party snack foods',
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'haberdashery',
#   'kitchen',
#   'prepared meals',
#   'condiments',
#   'cooking oils'],
#  ['department5',
#   'department9',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'beverages hot',
#   'deodorants-soap',
#   'haircare',
#   'sanitary pads',
#   'milk-cream',
#   'beef',
#   'stationary',
#   'small goods2',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'fuels-garden aids',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'small goods',
#   'fruit',
#   'vegetables',
#   'variety misc',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'pet foods',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'deodorants-soap',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'pet food',
#   'pork',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'department122'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'cleaners-polishers',
#   'coffee',
#   'laundry needs',
#   'party snack foods',
#   'soft drinks',
#   'sanitary pads',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'department122',
#   'small goods2'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'jams-spreads',
#   'party snack foods',
#   'wrapping',
#   'cheese',
#   'milk-cream',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'prepared meals',
#   'condiments',
#   'department122',
#   'imported cheese',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'wrapping',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'stationary'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'frozen foods',
#   'fuels-garden aids',
#   'spices',
#   'jams-spreads',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'soft drinks',
#   'deodorants-soap',
#   'mens toiletries',
#   'haircare',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'pork',
#   'prepared meals',
#   'preserving needs',
#   'cooking oils',
#   'department130',
#   'trim pork'],
#  ['bread and cake',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'fuels-garden aids',
#   'party snack foods',
#   'tissues-paper prd',
#   'beverages hot',
#   'haircare',
#   'lotions-creams',
#   'lamb',
#   'brushware',
#   'small goods2'],
#  ['juice-sat-cord-ms',
#   'cigs-tobacco pkts',
#   'soft drinks',
#   'fruit',
#   'vegetables',
#   '750ml white imp'],
#  ['juice-sat-cord-ms',
#   'canned fish-meat',
#   'canned vegetables',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'soft drinks',
#   'deodorants-soap',
#   'dental needs',
#   'cheese',
#   'margarine',
#   'pet food',
#   'potatoes',
#   'vegetables',
#   'condiments',
#   'cooking oils',
#   'small goods2',
#   'department137',
#   'casks white wine',
#   '750ml white nz'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'soft drinks',
#   'deodorants-soap',
#   'dental needs',
#   'sanitary pads',
#   'cough-cold-pain',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'prepared meals',
#   'bake off products',
#   'department122',
#   'department211'],
#  ['bread and cake',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'jams-spreads',
#   'insecticides',
#   'deodorants-soap',
#   'milk-cream',
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ['baking needs',
#   'breakfast food',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'mens toiletries',
#   'milk-cream',
#   'pet food',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary'],
#  ['grocery misc', 'cigs-tobacco pkts'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned fruit',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'tissues-paper prd',
#   'wrapping',
#   'haircare',
#   'milk-cream',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   'condiments'],
#  ['department1'],
#  ['department5',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'medicines',
#   'sanitary pads',
#   'cough-cold-pain',
#   'cheese',
#   'margarine',
#   'fruit',
#   'kitchen',
#   'prepared meals',
#   'preserving needs',
#   'cooking oils'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'milk-cream',
#   'fruit',
#   'vegetables',
#   'stationary'],
#  ['department5',
#   'bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'frozen foods',
#   'pet foods',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   'prepared meals',
#   'small goods2',
#   'department137'],
#  ['department4',
#   'baby needs',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'insecticides',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'beverages hot',
#   'deodorants-soap',
#   'haircare',
#   'cheese',
#   'margarine',
#   'vegetables',
#   'brushware',
#   'prepared meals',
#   'department137'],
#  ['department5',
#   'bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'milk-cream',
#   'manchester',
#   'prepared meals',
#   'department122'],
#  ['juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'frozen foods',
#   'party snack foods',
#   'fruit',
#   'bake off products'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'beef',
#   'pet food',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'small goods2'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'canned fish-meat',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'coffee',
#   'deod-disinfectant',
#   'frozen foods',
#   'insecticides',
#   'soft drinks',
#   'margarine',
#   'poultry',
#   'potatoes',
#   'vegetables',
#   'variety misc',
#   'stationary',
#   'cooking oils',
#   'department137'],
#  ['department2',
#   'grocery misc',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'razor blades',
#   'jams-spreads',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'beverages hot',
#   'deodorants-soap',
#   'haircare',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'pork',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'electrical',
#   'stationary',
#   'cooking oils'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'spices',
#   'insecticides',
#   'pet foods',
#   'beverages hot',
#   'haircare',
#   'meat misc',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'prepared meals',
#   'bake off products',
#   'department137'],
#  ['bread and cake',
#   'canned fish-meat',
#   'breakfast food',
#   'confectionary',
#   'spices',
#   'pet foods',
#   'wrapping',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'poultry',
#   'department79',
#   'potatoes',
#   'vegetables',
#   'prepared meals',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   'beef',
#   'hogget',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'prepared meals',
#   'small goods2'],
#  ['department1',
#   'bread and cake',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'cleaners-polishers',
#   'coffee',
#   'confectionary',
#   'frozen foods',
#   'jams-spreads',
#   'party snack foods',
#   'soft drinks',
#   'sanitary pads',
#   'milk-cream',
#   'electrical',
#   'department130'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'lamb',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'department122',
#   'department137'],
#  ['baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'health food other',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'bake off products',
#   'department137'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'soft drinks',
#   'margarine',
#   'fruit',
#   'stationary',
#   'department137'],
#  ['department2',
#   'juice-sat-cord-ms',
#   'cleaners-polishers',
#   'pet foods',
#   'soft drinks',
#   'beef',
#   'pet food',
#   'pork',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'kitchen',
#   'small goods2',
#   'department137'],
#  ['baking needs',
#   'frozen foods',
#   'fuels-garden aids',
#   'jams-spreads',
#   'insecticides',
#   'soft drinks',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'kitchen',
#   'prepared meals',
#   'cooking oils',
#   '750ml white nz'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'spices',
#   'laundry needs',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'cheese',
#   'department79',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'prepared meals',
#   'department122',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'department122',
#   'small goods2'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'frozen foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'deodorants-soap',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'produce misc',
#   'fruit',
#   'vegetables'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'coffee',
#   'confectionary',
#   'tissues-paper prd',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'variety misc',
#   'stationary',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'spices',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'health food other',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'small goods2',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'frozen foods',
#   'pet foods',
#   'soft drinks',
#   'milk-cream',
#   'cold-meats',
#   'dairy foods',
#   'department79',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'condiments',
#   'department130',
#   'department137'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'cleaners-polishers',
#   'puddings-deserts',
#   'jams-spreads',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'soft drinks',
#   'haircare',
#   'cough-cold-pain',
#   'cheese',
#   'fruit',
#   'condiments'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'dental needs',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'beef',
#   'pork',
#   'fruit',
#   'stationary',
#   'prepared meals',
#   'cooking oils',
#   'bake off products',
#   'offal',
#   'department137',
#   'sparkling nz'],
#  ['bread and cake',
#   'tea',
#   'biscuits',
#   'cleaners-polishers',
#   'confectionary',
#   'deod-disinfectant',
#   'frozen foods',
#   'spices',
#   'pet foods',
#   'laundry needs',
#   'soft drinks',
#   'health food other',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'fruit',
#   'department130',
#   '750ml white nz',
#   'department211'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'cleaners-polishers',
#   'fuels-garden aids',
#   'tissues-paper prd',
#   'milk-cream',
#   'beef',
#   'department79',
#   'kitchen',
#   'department122'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'spices',
#   'jams-spreads',
#   'party snack foods',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'small goods2'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'department130',
#   'small goods2',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'biscuits',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'milk-cream',
#   'dairy foods',
#   'fruit',
#   'stationary',
#   'imported cheese',
#   'department137',
#   'department210'],
#  ['department5',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'fruit',
#   'brushware',
#   'kitchen',
#   'condiments',
#   'department210'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'beverages hot',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'fruit',
#   'vegetables',
#   'small goods2',
#   '750ml white nz'],
#  ['department5',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'biscuits',
#   'breakfast food',
#   'puddings-deserts',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'pet food',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'brushware',
#   'kitchen',
#   'prepared meals',
#   'bake off products'],
#  ['baby needs',
#   'bread and cake',
#   'biscuits',
#   'coffee',
#   'dishcloths-scour',
#   'lotions-creams',
#   'cheese',
#   'cold-meats',
#   'margarine',
#   'fruit',
#   'vegetables',
#   'variety misc',
#   'kitchen'],
#  ['department1',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'sauces-gravy-pkle',
#   'fuels-garden aids',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'cheese',
#   'small goods',
#   'department79',
#   'fruit',
#   'vegetables'],
#  ['tea',
#   'canned fish-meat',
#   'canned vegetables',
#   'breakfast food',
#   'frozen foods',
#   'razor blades',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'milk-cream',
#   'margarine',
#   'dairy foods',
#   'beef'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'dishcloths-scour',
#   'frozen foods',
#   'spices',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'department79',
#   'potatoes',
#   'kitchen',
#   'small goods2',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'insecticides',
#   'pet foods',
#   'party snack foods',
#   'wrapping',
#   'soft drinks',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'cooking oils',
#   'small goods2'],
#  ['cleaners-polishers',
#   'deod-disinfectant',
#   'razor blades',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'stationary'],
#  ['department1',
#   'bread and cake',
#   'juice-sat-cord-ms',
#   'tea',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   'frozen foods',
#   'jams-spreads',
#   'laundry needs',
#   'tissues-paper prd',
#   'soft drinks',
#   'deodorants-soap',
#   'sanitary pads',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'vegetables',
#   'bake off products',
#   'department124'],
#  ['baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'cooking oils'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'razor blades',
#   'fuels-garden aids',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'lotions-creams',
#   'cheese',
#   'margarine',
#   'small goods',
#   'beef',
#   'lamb',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'small goods2'],
#  ['bread and cake',
#   'biscuits',
#   'cleaners-polishers',
#   'coffee',
#   'puddings-deserts',
#   'frozen foods',
#   'insecticides',
#   'pet foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'deodorants-soap',
#   'haircare',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'fruit drinks',
#   'vegetables',
#   'stationary',
#   'department130'],
#  ['grocery misc', 'cigs-tobacco pkts', 'coffee', 'stationary'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'jams-spreads',
#   'insecticides',
#   'party snack foods',
#   'tissues-paper prd',
#   'cheese',
#   'cold-meats',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'potatoes',
#   'variety misc',
#   'stationary',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'deodorants-soap',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'small goods2'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'health food other',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'pet food',
#   'pork',
#   'fruit',
#   'vegetables',
#   'bake off products',
#   'department130',
#   'small goods2',
#   'department210'],
#  ['department1',
#   'bread and cake',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'insecticides',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'pet food',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'prepared meals',
#   'preserving needs',
#   'department137'],
#  ['bread and cake',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'frozen foods',
#   'razor blades',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'dental needs',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'dairy foods',
#   'pet food',
#   'poultry',
#   'fruit',
#   'stationary',
#   'department137'],
#  ['baking needs',
#   'juice-sat-cord-ms',
#   'canned fish-meat',
#   'canned fruit',
#   'cleaners-polishers',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'pkt-canned soup',
#   'soft drinks',
#   'haircare',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'dairy foods',
#   'pet food',
#   'department122',
#   'department137'],
#  ['department2',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'party snack foods',
#   'wrapping',
#   'cheese',
#   'deli gourmet',
#   'margarine',
#   'small goods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'frozen foods',
#   'spices',
#   'jams-spreads',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'haircare',
#   'lotions-creams',
#   'cheese',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'pork',
#   'produce misc',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'prepared meals',
#   'cooking oils',
#   'department137',
#   '750ml white imp'],
#  ['department4',
#   'grocery misc',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'pork',
#   'department211'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'spices',
#   'insecticides',
#   'pet foods',
# ...
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'deodorants-soap',
#   'mens toiletries',
#   'haircare',
#   'dental needs',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'poultry',
#   'vegetables',
#   'prepared meals',
#   'cooking oils',
#   'small goods2',
#   'department137'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'coffee',
#   'sauces-gravy-pkle',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'poultry',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'department122',
#   'offal',
#   'department137'],
#  ['department1',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'jams-spreads',
#   'party snack foods',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'department122'],
#  ['department1',
#   'department2',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'mens toiletries',
#   'medicines',
#   'dental needs',
#   'lotions-creams',
#   'cough-cold-pain',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'beef',
#   'department79',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'condiments',
#   'small goods2',
#   'department137',
#   'department213'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'coffee',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'wrapping',
#   'dried vegetables',
#   'milk-cream',
#   'dairy foods',
#   'beef',
#   'lamb',
#   'pet food',
#   'poultry',
#   'stationary',
#   'prepared meals'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fish-meat',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'pkt-canned soup',
#   'deodorants-soap',
#   'haircare',
#   'lotions-creams',
#   'margarine',
#   'small goods',
#   'beef',
#   'poultry',
#   'vegetables',
#   'prepared meals',
#   'department137',
#   '750ml white nz',
#   '750ml red nz'],
#  ['cigs-tobacco pkts',
#   'confectionary',
#   'laundry needs',
#   'party snack foods',
#   'deodorants-soap',
#   'lamb',
#   'vegetables',
#   'department210'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'canned fish-meat',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'insecticides',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'cheese',
#   'margarine',
#   'produce misc',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'electrical',
#   'stationary',
#   'bake off products',
#   'small goods2',
#   'department137',
#   '750ml red nz'],
#  ['bread and cake',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'confectionary',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'wrapping',
#   'soft drinks',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'beef',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'department130',
#   'department137'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'frozen foods',
#   'razor blades',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'cheese',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'prepared meals',
#   'department137'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'dishcloths-scour',
#   'frozen foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'pkt-canned soup',
#   'soft drinks',
#   'deodorants-soap',
#   'haircare',
#   'chickens',
#   'milk-cream',
#   'cold-meats',
#   'deli gourmet',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'kitchen',
#   'prepared meals',
#   'imported cheese',
#   'department137'],
#  ['baking needs',
#   'confectionary',
#   'frozen foods',
#   'laundry needs',
#   'milk-cream',
#   'beef',
#   'hogget',
#   'lamb',
#   'vegetables',
#   'stationary',
#   'department210'],
#  ['department1',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'confectionary',
#   'spices',
#   'health&beauty misc',
#   'milk-cream',
#   'fruit',
#   'vegetables'],
#  ['cigs-tobacco pkts', 'haircare', '750ml white imp', '750ml red imp'],
#  ['department1',
#   'biscuits',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'cold-meats',
#   'deli gourmet',
#   'dairy foods',
#   'delicatessen misc',
#   'department79',
#   'fruit',
#   'vegetables',
#   'department122'],
#  ['juice-sat-cord-ms',
#   'biscuits',
#   'breakfast food',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'beverages hot',
#   'deodorants-soap',
#   'dental needs',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'prepared meals',
#   'non host support'],
#  ['bread and cake',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'coffee',
#   'confectionary',
#   'frozen foods',
#   'pet foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'deodorants-soap',
#   'dental needs',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'beef',
#   'department79',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'department122'],
#  ['bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'canned fish-meat',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'margarine',
#   'small goods',
#   'beef',
#   'pork',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'small goods2'],
#  ['department1',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'confectionary',
#   'pet foods',
#   'wrapping',
#   'milk-cream',
#   'dairy foods',
#   'fruit',
#   'stationary',
#   'bake off products',
#   'department122',
#   'department211'],
#  ['juice-sat-cord-ms',
#   'canned fish-meat',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'milk-cream',
#   'department130',
#   'sparkling nz',
#   'department210'],
#  ['canned vegetables',
#   'breakfast food',
#   'party snack foods',
#   'meat misc',
#   'milk-cream',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'department122',
#   'department130',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'biscuits',
#   'confectionary',
#   'jams-spreads',
#   'laundry needs',
#   'tissues-paper prd',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'fruit',
#   'potatoes',
#   'stationary',
#   'department211',
#   'department213'],
#  ['bread and cake',
#   'baking needs',
#   'biscuits',
#   'coffee',
#   'confectionary',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'milk-cream',
#   'lamb',
#   'pet food',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'department130'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'jams-spreads',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'bake off products',
#   'department122'],
#  ['department1',
#   'bread and cake',
#   'tea',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'puddings-deserts',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'mens toiletries',
#   'dental needs',
#   'lotions-creams',
#   'cheese',
#   'milk-cream',
#   'deli gourmet',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'kitchen',
#   'small goods2',
#   'department137',
#   '750ml red imp'],
#  ['department3',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'coffee',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'sanitary pads',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'pet food',
#   'fruit',
#   'department130'],
#  ['bread and cake',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'haircare',
#   'dairy foods',
#   'variety misc',
#   'stationary',
#   'department137'],
#  ['juice-sat-cord-ms',
#   'sauces-gravy-pkle',
#   'fuels-garden aids',
#   'insecticides',
#   'tissues-paper prd',
#   'milk-cream',
#   'vegetables',
#   'variety misc',
#   'small goods2',
#   'department137',
#   'casks white wine'],
#  ['department1',
#   'baby needs',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'tea',
#   'biscuits',
#   'canned vegetables',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'department79',
#   'vegetables',
#   'stationary',
#   'cooking oils',
#   'department130',
#   'small goods2',
#   'department137'],
#  ['department1',
#   'juice-sat-cord-ms',
#   'cleaners-polishers',
#   'coffee',
#   'frozen foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'milk-cream',
#   'small goods',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables',
#   'stationary',
#   'department130'],
#  ['baby needs',
#   'bread and cake',
#   'baking needs',
#   'tea',
#   'biscuits',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'spices',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'sanitary pads',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'brushware',
#   'kitchen',
#   'department137'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'breakfast food',
#   'cleaners-polishers',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'tissues-paper prd',
#   'soft drinks',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'deli gourmet',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'delicatessen misc',
#   'beef',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'bake off products',
#   'department122',
#   'small goods2',
#   'imported cheese',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'coffee',
#   'confectionary',
#   'deod-disinfectant',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'tissues-paper prd',
#   'wrapping',
#   'soft drinks',
#   'deodorants-soap',
#   'dental needs',
#   'cheese',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'prepared meals',
#   'cooking oils',
#   'bake off products',
#   'department122'],
#  ['bread and cake',
#   'baking needs',
#   'breakfast food',
#   'haircare',
#   'lotions-creams',
#   'margarine',
#   'small goods',
#   'dairy foods',
#   'fruit',
#   'vegetables',
#   'kitchen'],
#  ['cigs-tobacco pkts',
#   'frozen foods',
#   'party snack foods',
#   'soft drinks',
#   'milk-cream',
#   'beef',
#   'poultry',
#   'stationary',
#   'small goods2',
#   'department210'],
#  ['bread and cake',
#   'biscuits',
#   'breakfast food',
#   'milk-cream',
#   'cold-meats',
#   'vegetables',
#   'stationary',
#   'condiments',
#   'department130',
#   'department137'],
#  ['biscuits',
#   'confectionary',
#   'party snack foods',
#   'deodorants-soap',
#   'haircare',
#   'dental needs',
#   'sanitary pads',
#   'fruit',
#   'electrical',
#   'kitchen',
#   'prepared meals',
#   'bake off products'],
#  ['department1',
#   'bread and cake',
#   'biscuits',
#   'breakfast food',
#   'jams-spreads',
#   'insecticides',
#   'lotions-creams',
#   'milk-cream',
#   'beef',
#   'poultry',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'manchester',
#   'small goods2',
#   'trim pork'],
#  ['department1',
#   'bread and cake',
#   'baking needs',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'party snack foods',
#   'wrapping',
#   'small goods',
#   'vegetables',
#   'department122'],
#  ['baking needs',
#   'canned fruit',
#   'breakfast food',
#   'confectionary',
#   'frozen foods',
#   'milk-cream',
#   'margarine',
#   'small goods',
#   'beef',
#   'potatoes',
#   'vegetables',
#   'stationary',
#   'department137'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'puddings-deserts',
#   'dishcloths-scour',
#   'frozen foods',
#   'pet foods',
#   'laundry needs',
#   'party snack foods',
#   'soft drinks',
#   'milk-cream',
#   'dairy foods',
#   'beef',
#   'fruit',
#   'vegetables'],
#  ['department5',
#   'bread and cake',
#   'biscuits',
#   'sauces-gravy-pkle',
#   'frozen foods',
#   'jams-spreads',
#   'pet foods',
#   'soft drinks',
#   'cheese',
#   'milk-cream',
#   'cold-meats',
#   'dairy foods',
#   'delicatessen misc',
#   'pet food',
#   'vegetables',
#   'kitchen',
#   'stationary',
#   'department122',
#   'department137',
#   'casks red wine',
#   '750ml red imp'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'biscuits',
#   'canned fruit',
#   'canned vegetables',
#   'frozen foods',
#   'party snack foods',
#   'cold-meats',
#   'dairy foods',
#   'delicatessen misc',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'department122',
#   'department137'],
#  ['bread and cake',
#   'canned fruit',
#   'puddings-deserts',
#   'laundry needs',
#   'tissues-paper prd',
#   'dental needs',
#   'lotions-creams',
#   'margarine',
#   'dairy foods',
#   'beef',
#   'vegetables'],
#  ['department1',
#   'department2',
#   'grocery misc',
#   'baking needs',
#   'biscuits',
#   'cigs-tobacco pkts',
#   'sauces-gravy-pkle',
#   'confectionary',
#   'frozen foods',
#   'pet foods',
#   'party snack foods',
#   'soft drinks',
#   'sanitary pads',
#   'milk-cream',
#   'pet food',
#   'stationary'],
#  ['cigs-tobacco pkts',
#   'confectionary',
#   'frozen foods',
#   'soft drinks',
#   'milk-cream',
#   'beef',
#   'vegetables',
#   'kitchen',
#   'casks red wine'],
#  ['bread and cake',
#   'baking needs',
#   'tea',
#   'jams-spreads',
#   'insecticides',
#   'haircare',
#   'cough-cold-pain',
#   'cheese',
#   'deli gourmet',
#   'margarine',
#   'dairy foods',
#   'department130',
#   'imported cheese'],
#  ['department1',
#   'bread and cake',
#   'canned fish-meat',
#   'canned vegetables',
#   'cigs-tobacco pkts',
#   'cleaners-polishers',
#   'insecticides',
#   'pet foods',
#   'laundry needs',
#   'tissues-paper prd',
#   'soft drinks',
#   'milk-cream',
#   'small goods',
#   'dairy foods',
#   'fruit',
#   'potatoes',
#   'manchester'],
#  ['bread and cake',
#   'baking needs',
#   'juice-sat-cord-ms',
#   'canned vegetables',
#   'breakfast food',
#   'cigs-tobacco pkts',
#   'coffee',
#   'party snack foods',
#   'wrapping',
#   'soft drinks',
#   'dental needs',
#   'milk-cream',
#   'margarine',
#   'department79',
#   'vegetables',
#   'prepared meals',
#   'department211'],
#  ...]

# %% [markdown]
# Finally, we use the *apriori* algorithm to find association rules with a minimum support of $0.2$ and a minimum confidence of $0.7$.

# %%
mins = 0.2
minc = 0.7

results = list(apriori(transactions,min_support=mins,min_confidence=minc))

# %%
for i in range(len(results)):
    print(list(results[i][2][0][0]),'->',list(results[i][2][0][1]))
# Out:
# [] -> ['bread and cake']
# ['baking needs'] -> ['bread and cake']
# ['breakfast food'] -> ['baking needs']
# ['canned vegetables'] -> ['baking needs']
# ['jams-spreads'] -> ['baking needs']
# ['laundry needs'] -> ['baking needs']
# ['margarine'] -> ['baking needs']
# ['tissues-paper prd'] -> ['baking needs']
# ['wrapping'] -> ['baking needs']
# ['beef'] -> ['bread and cake']
# ['beef'] -> ['vegetables']
# ['biscuits'] -> ['bread and cake']
# ['biscuits'] -> ['fruit']
# ['breakfast food'] -> ['bread and cake']
# ['canned fruit'] -> ['bread and cake']
# ['canned vegetables'] -> ['bread and cake']
# ['cheese'] -> ['bread and cake']
# ['cleaners-polishers'] -> ['bread and cake']
# ['confectionary'] -> ['bread and cake']
# ['dairy foods'] -> ['bread and cake']
# ['department137'] -> ['bread and cake']
# ['frozen foods'] -> ['bread and cake']
# ['fruit'] -> ['bread and cake']
# ['jams-spreads'] -> ['bread and cake']
# ['juice-sat-cord-ms'] -> ['bread and cake']
# ['laundry needs'] -> ['bread and cake']
# ['margarine'] -> ['bread and cake']
# ['bread and cake'] -> ['milk-cream']
# ['party snack foods'] -> ['bread and cake']
# ['pet foods'] -> ['bread and cake']
# ['prepared meals'] -> ['bread and cake']
# ['sauces-gravy-pkle'] -> ['bread and cake']
# ['small goods'] -> ['bread and cake']
# ['soft drinks'] -> ['bread and cake']
# ['stationary'] -> ['bread and cake']
# ['tissues-paper prd'] -> ['bread and cake']
# ['vegetables'] -> ['bread and cake']
# ['wrapping'] -> ['bread and cake']
# ['breakfast food'] -> ['fruit']
# ['canned fruit'] -> ['fruit']
# ['canned vegetables'] -> ['frozen foods']
# ['canned vegetables'] -> ['fruit']
# ['canned vegetables'] -> ['vegetables']
# ['cheese'] -> ['vegetables']
# ['dairy foods'] -> ['fruit']
# ['dairy foods'] -> ['vegetables']
# ['prepared meals'] -> ['frozen foods']
# ['fruit'] -> ['vegetables']
# ['pet foods'] -> ['vegetables']
# ['sauces-gravy-pkle'] -> ['vegetables']
# ['wrapping'] -> ['vegetables']
# ['baking needs', 'beef'] -> ['bread and cake']
# ['baking needs', 'biscuits'] -> ['bread and cake']
# ['biscuits', 'breakfast food'] -> ['baking needs']
# ['baking needs', 'biscuits'] -> ['frozen foods']
# ['baking needs', 'biscuits'] -> ['fruit']
# ['biscuits', 'juice-sat-cord-ms'] -> ['baking needs']
# ['biscuits', 'margarine'] -> ['baking needs']
# ['baking needs', 'party snack foods'] -> ['biscuits']
# ['biscuits', 'sauces-gravy-pkle'] -> ['baking needs']
# ['biscuits', 'tissues-paper prd'] -> ['baking needs']
# ['baking needs', 'biscuits'] -> ['vegetables']
# ['baking needs', 'breakfast food'] -> ['bread and cake']
# ['baking needs', 'canned vegetables'] -> ['bread and cake']
# ['baking needs', 'cheese'] -> ['bread and cake']
# ['baking needs', 'dairy foods'] -> ['bread and cake']
# ['baking needs', 'department137'] -> ['bread and cake']
# ['baking needs', 'frozen foods'] -> ['bread and cake']
# ['baking needs', 'bread and cake'] -> ['fruit']
# ['baking needs', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['baking needs', 'margarine'] -> ['bread and cake']
# ['baking needs', 'bread and cake'] -> ['milk-cream']
# ['baking needs', 'party snack foods'] -> ['bread and cake']
# ['baking needs', 'pet foods'] -> ['bread and cake']
# ['baking needs', 'sauces-gravy-pkle'] -> ['bread and cake']
# ['baking needs', 'soft drinks'] -> ['bread and cake']
# ['baking needs', 'tissues-paper prd'] -> ['bread and cake']
# ['baking needs', 'bread and cake'] -> ['vegetables']
# ['baking needs', 'breakfast food'] -> ['frozen foods']
# ['baking needs', 'breakfast food'] -> ['fruit']
# ['baking needs', 'breakfast food'] -> ['vegetables']
# ['baking needs', 'cheese'] -> ['fruit']
# ['baking needs', 'cheese'] -> ['milk-cream']
# ['baking needs', 'cheese'] -> ['vegetables']
# ['baking needs', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['baking needs', 'margarine'] -> ['frozen foods']
# ['baking needs', 'party snack foods'] -> ['frozen foods']
# ['baking needs', 'sauces-gravy-pkle'] -> ['frozen foods']
# ['baking needs', 'tissues-paper prd'] -> ['frozen foods']
# ['baking needs', 'frozen foods'] -> ['vegetables']
# ['fruit', 'margarine'] -> ['baking needs']
# ['baking needs', 'fruit'] -> ['milk-cream']
# ['fruit', 'sauces-gravy-pkle'] -> ['baking needs']
# ['baking needs', 'tissues-paper prd'] -> ['fruit']
# ['baking needs', 'fruit'] -> ['vegetables']
# ['margarine', 'juice-sat-cord-ms'] -> ['baking needs']
# ['sauces-gravy-pkle', 'juice-sat-cord-ms'] -> ['baking needs']
# ['tissues-paper prd', 'juice-sat-cord-ms'] -> ['baking needs']
# ['baking needs', 'juice-sat-cord-ms'] -> ['vegetables']
# ['margarine', 'milk-cream'] -> ['baking needs']
# ['margarine', 'party snack foods'] -> ['baking needs']
# ['sauces-gravy-pkle', 'margarine'] -> ['baking needs']
# ['tissues-paper prd', 'margarine'] -> ['baking needs']
# ['baking needs', 'margarine'] -> ['vegetables']
# ['sauces-gravy-pkle', 'milk-cream'] -> ['baking needs']
# ['baking needs', 'tissues-paper prd'] -> ['milk-cream']
# ['baking needs', 'milk-cream'] -> ['vegetables']
# ['sauces-gravy-pkle', 'party snack foods'] -> ['baking needs']
# ['tissues-paper prd', 'party snack foods'] -> ['baking needs']
# ['baking needs', 'party snack foods'] -> ['vegetables']
# ['baking needs', 'pet foods'] -> ['vegetables']
# ['sauces-gravy-pkle', 'tissues-paper prd'] -> ['baking needs']
# ['baking needs', 'sauces-gravy-pkle'] -> ['vegetables']
# ['baking needs', 'tissues-paper prd'] -> ['vegetables']
# ['beef', 'bread and cake'] -> ['frozen foods']
# ['beef', 'bread and cake'] -> ['fruit']
# ['beef', 'bread and cake'] -> ['milk-cream']
# ['beef', 'bread and cake'] -> ['vegetables']
# ['fruit', 'beef'] -> ['vegetables']
# ['biscuits', 'breakfast food'] -> ['bread and cake']
# ['biscuits', 'cheese'] -> ['bread and cake']
# ['biscuits', 'department137'] -> ['bread and cake']
# ['biscuits', 'bread and cake'] -> ['frozen foods']
# ['biscuits', 'bread and cake'] -> ['fruit']
# ['biscuits', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['biscuits', 'margarine'] -> ['bread and cake']
# ['biscuits', 'bread and cake'] -> ['milk-cream']
# ['biscuits', 'party snack foods'] -> ['bread and cake']
# ['pet foods', 'biscuits'] -> ['bread and cake']
# ['biscuits', 'sauces-gravy-pkle'] -> ['bread and cake']
# ['biscuits', 'soft drinks'] -> ['bread and cake']
# ['biscuits', 'tissues-paper prd'] -> ['bread and cake']
# ['biscuits', 'bread and cake'] -> ['vegetables']
# ['biscuits', 'breakfast food'] -> ['frozen foods']
# ['biscuits', 'frozen foods'] -> ['fruit']
# ['biscuits', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['biscuits', 'margarine'] -> ['frozen foods']
# ['biscuits', 'milk-cream'] -> ['frozen foods']
# ['biscuits', 'party snack foods'] -> ['frozen foods']
# ['biscuits', 'sauces-gravy-pkle'] -> ['frozen foods']
# ['biscuits', 'tissues-paper prd'] -> ['frozen foods']
# ['biscuits', 'frozen foods'] -> ['vegetables']
# ['biscuits', 'juice-sat-cord-ms'] -> ['fruit']
# ['biscuits', 'margarine'] -> ['fruit']
# ['fruit', 'biscuits'] -> ['milk-cream']
# ['biscuits', 'party snack foods'] -> ['fruit']
# ['biscuits', 'sauces-gravy-pkle'] -> ['fruit']
# ['biscuits', 'tissues-paper prd'] -> ['fruit']
# ['fruit', 'biscuits'] -> ['vegetables']
# ['margarine', 'juice-sat-cord-ms'] -> ['biscuits']
# ['party snack foods', 'juice-sat-cord-ms'] -> ['biscuits']
# ['margarine', 'party snack foods'] -> ['biscuits']
# ['biscuits', 'margarine'] -> ['vegetables']
# ['party snack foods', 'milk-cream'] -> ['biscuits']
# ['biscuits', 'vegetables'] -> ['milk-cream']
# ['sauces-gravy-pkle', 'party snack foods'] -> ['biscuits']
# ['tissues-paper prd', 'party snack foods'] -> ['biscuits']
# ['vegetables', 'party snack foods'] -> ['biscuits']
# ['biscuits', 'sauces-gravy-pkle'] -> ['vegetables']
# ['biscuits', 'tissues-paper prd'] -> ['vegetables']
# ['bread and cake', 'breakfast food'] -> ['frozen foods']
# ['bread and cake', 'breakfast food'] -> ['fruit']
# ['bread and cake', 'breakfast food'] -> ['milk-cream']
# ['bread and cake', 'breakfast food'] -> ['vegetables']
# ['bread and cake', 'canned vegetables'] -> ['fruit']
# ['bread and cake', 'canned vegetables'] -> ['vegetables']
# ['frozen foods', 'cheese'] -> ['bread and cake']
# ['bread and cake', 'cheese'] -> ['fruit']
# ['margarine', 'cheese'] -> ['bread and cake']
# ['bread and cake', 'cheese'] -> ['milk-cream']
# ['bread and cake', 'cheese'] -> ['vegetables']
# ['confectionary', 'bread and cake'] -> ['fruit']
# ['confectionary', 'bread and cake'] -> ['milk-cream']
# ['dairy foods', 'bread and cake'] -> ['fruit']
# ['dairy foods', 'bread and cake'] -> ['milk-cream']
# ['dairy foods', 'bread and cake'] -> ['vegetables']
# ['frozen foods', 'department137'] -> ['bread and cake']
# ['bread and cake', 'department137'] -> ['fruit']
# ['bread and cake', 'department137'] -> ['milk-cream']
# ['bread and cake', 'department137'] -> ['vegetables']
# ['bread and cake', 'frozen foods'] -> ['fruit']
# ['frozen foods', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['margarine', 'frozen foods'] -> ['bread and cake']
# ['bread and cake', 'frozen foods'] -> ['milk-cream']
# ['bread and cake', 'party snack foods'] -> ['frozen foods']
# ['pet foods', 'frozen foods'] -> ['bread and cake']
# ['sauces-gravy-pkle', 'bread and cake'] -> ['frozen foods']
# ['bread and cake', 'soft drinks'] -> ['frozen foods']
# ['tissues-paper prd', 'frozen foods'] -> ['bread and cake']
# ['bread and cake', 'frozen foods'] -> ['vegetables']
# ['bread and cake', 'juice-sat-cord-ms'] -> ['fruit']
# ['bread and cake', 'margarine'] -> ['fruit']
# ['fruit', 'bread and cake'] -> ['milk-cream']
# ['bread and cake', 'party snack foods'] -> ['fruit']
# ['pet foods', 'bread and cake'] -> ['fruit']
# ['sauces-gravy-pkle', 'bread and cake'] -> ['fruit']
# ['bread and cake', 'soft drinks'] -> ['fruit']
# ['tissues-paper prd', 'bread and cake'] -> ['fruit']
# ['fruit', 'bread and cake'] -> ['vegetables']
# ['margarine', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['bread and cake', 'juice-sat-cord-ms'] -> ['milk-cream']
# ['party snack foods', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['sauces-gravy-pkle', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['tissues-paper prd', 'juice-sat-cord-ms'] -> ['bread and cake']
# ['bread and cake', 'juice-sat-cord-ms'] -> ['vegetables']
# ['bread and cake', 'margarine'] -> ['milk-cream']
# ['margarine', 'party snack foods'] -> ['bread and cake']
# ['sauces-gravy-pkle', 'margarine'] -> ['bread and cake']
# ['tissues-paper prd', 'margarine'] -> ['bread and cake']
# ['bread and cake', 'margarine'] -> ['vegetables']
# ['bread and cake', 'party snack foods'] -> ['milk-cream']
# ['pet foods', 'bread and cake'] -> ['milk-cream']
# ['sauces-gravy-pkle', 'bread and cake'] -> ['milk-cream']
# ['bread and cake', 'soft drinks'] -> ['milk-cream']
# ['tissues-paper prd', 'bread and cake'] -> ['milk-cream']
# ['bread and cake', 'milk-cream'] -> ['vegetables']
# ['sauces-gravy-pkle', 'party snack foods'] -> ['bread and cake']
# ['tissues-paper prd', 'party snack foods'] -> ['bread and cake']
# ['bread and cake', 'party snack foods'] -> ['vegetables']
# ['pet foods', 'bread and cake'] -> ['vegetables']
# ['sauces-gravy-pkle', 'tissues-paper prd'] -> ['bread and cake']
# ['sauces-gravy-pkle', 'bread and cake'] -> ['vegetables']
# ['vegetables', 'soft drinks'] -> ['bread and cake']
# ['tissues-paper prd', 'bread and cake'] -> ['vegetables']
# ['fruit', 'breakfast food'] -> ['milk-cream']
# ['fruit', 'breakfast food'] -> ['vegetables']
# ['fruit', 'cheese'] -> ['milk-cream']
# ['fruit', 'cheese'] -> ['vegetables']
# ['milk-cream', 'cheese'] -> ['vegetables']
# ['dairy foods', 'fruit'] -> ['vegetables']
# ['fruit', 'department137'] -> ['vegetables']
# ['frozen foods', 'juice-sat-cord-ms'] -> ['fruit']
# ['fruit', 'frozen foods'] -> ['milk-cream']
# ['party snack foods', 'frozen foods'] -> ['fruit']
# ['sauces-gravy-pkle', 'frozen foods'] -> ['fruit']
# ['tissues-paper prd', 'frozen foods'] -> ['fruit']
# ['fruit', 'frozen foods'] -> ['vegetables']
# ['margarine', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['party snack foods', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['sauces-gravy-pkle', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['tissues-paper prd', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['frozen foods', 'juice-sat-cord-ms'] -> ['vegetables']
# ['tissues-paper prd', 'margarine'] -> ['frozen foods']
# ['margarine', 'frozen foods'] -> ['vegetables']
# ['frozen foods', 'milk-cream'] -> ['vegetables']
# ['sauces-gravy-pkle', 'party snack foods'] -> ['frozen foods']
# ['tissues-paper prd', 'party snack foods'] -> ['frozen foods']
# ['party snack foods', 'frozen foods'] -> ['vegetables']
# ['pet foods', 'frozen foods'] -> ['vegetables']
# ['sauces-gravy-pkle', 'tissues-paper prd'] -> ['frozen foods']
# ['sauces-gravy-pkle', 'frozen foods'] -> ['vegetables']
# ['tissues-paper prd', 'frozen foods'] -> ['vegetables']
# ['fruit', 'juice-sat-cord-ms'] -> ['milk-cream']
# ['party snack foods', 'juice-sat-cord-ms'] -> ['fruit']
# ['sauces-gravy-pkle', 'juice-sat-cord-ms'] -> ['fruit']
# ['tissues-paper prd', 'juice-sat-cord-ms'] -> ['fruit']
# ['fruit', 'juice-sat-cord-ms'] -> ['vegetables']
# ['fruit', 'margarine'] -> ['milk-cream']
# ['tissues-paper prd', 'margarine'] -> ['fruit']
# ['fruit', 'margarine'] -> ['vegetables']
# ['fruit', 'party snack foods'] -> ['milk-cream']
# ['fruit', 'pet foods'] -> ['milk-cream']
# ['fruit', 'sauces-gravy-pkle'] -> ['milk-cream']
# ['fruit', 'tissues-paper prd'] -> ['milk-cream']
# ['fruit', 'milk-cream'] -> ['vegetables']
# ['tissues-paper prd', 'party snack foods'] -> ['fruit']
# ['fruit', 'party snack foods'] -> ['vegetables']
# ['fruit', 'pet foods'] -> ['vegetables']
# ['fruit', 'sauces-gravy-pkle'] -> ['vegetables']
# ['fruit', 'soft drinks'] -> ['vegetables']
# ['fruit', 'tissues-paper prd'] -> ['vegetables']
# ['margarine', 'juice-sat-cord-ms'] -> ['vegetables']
# ['milk-cream', 'juice-sat-cord-ms'] -> ['vegetables']
# ['sauces-gravy-pkle', 'juice-sat-cord-ms'] -> ['vegetables']
# ['tissues-paper prd', 'juice-sat-cord-ms'] -> ['vegetables']
# ['margarine', 'milk-cream'] -> ['vegetables']
# ['sauces-gravy-pkle', 'margarine'] -> ['vegetables']
# ['tissues-paper prd', 'margarine'] -> ['vegetables']
# ['pet foods', 'milk-cream'] -> ['vegetables']
# ['sauces-gravy-pkle', 'milk-cream'] -> ['vegetables']
# ['tissues-paper prd', 'milk-cream'] -> ['vegetables']
# ['sauces-gravy-pkle', 'party snack foods'] -> ['vegetables']
# ['tissues-paper prd', 'party snack foods'] -> ['vegetables']
# ['sauces-gravy-pkle', 'tissues-paper prd'] -> ['vegetables']
# ['baking needs', 'biscuits', 'bread and cake'] -> ['frozen foods']
# ['baking needs', 'biscuits', 'bread and cake'] -> ['fruit']
# ['baking needs', 'biscuits', 'margarine'] -> ['bread and cake']
# ['baking needs', 'biscuits', 'bread and cake'] -> ['milk-cream']
# ['baking needs', 'biscuits', 'party snack foods'] -> ['bread and cake']
# ['baking needs', 'biscuits', 'bread and cake'] -> ['vegetables']
# ['baking needs', 'biscuits', 'frozen foods'] -> ['fruit']
# ['baking needs', 'biscuits', 'frozen foods'] -> ['milk-cream']
# ['baking needs', 'biscuits', 'frozen foods'] -> ['vegetables']
# ['baking needs', 'biscuits', 'fruit'] -> ['milk-cream']
# ['baking needs', 'biscuits', 'fruit'] -> ['vegetables']
# ['baking needs', 'bread and cake', 'frozen foods'] -> ['fruit']
# ['baking needs', 'bread and cake', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['baking needs', 'bread and cake', 'margarine'] -> ['frozen foods']
# ['baking needs', 'bread and cake', 'frozen foods'] -> ['milk-cream']
# ['baking needs', 'bread and cake', 'party snack foods'] -> ['frozen foods']
# ['baking needs', 'tissues-paper prd', 'bread and cake'] -> ['frozen foods']
# ['baking needs', 'bread and cake', 'frozen foods'] -> ['vegetables']
# ['baking needs', 'bread and cake', 'juice-sat-cord-ms'] -> ['fruit']
# ['baking needs', 'bread and cake', 'margarine'] -> ['fruit']
# ['baking needs', 'bread and cake', 'fruit'] -> ['milk-cream']
# ['baking needs', 'tissues-paper prd', 'bread and cake'] -> ['fruit']
# ['baking needs', 'bread and cake', 'fruit'] -> ['vegetables']
# ['baking needs', 'bread and cake', 'juice-sat-cord-ms'] -> ['milk-cream']
# ['baking needs', 'bread and cake', 'juice-sat-cord-ms'] -> ['vegetables']
# ['baking needs', 'bread and cake', 'margarine'] -> ['milk-cream']
# ['baking needs', 'bread and cake', 'margarine'] -> ['vegetables']
# ['baking needs', 'tissues-paper prd', 'bread and cake'] -> ['milk-cream']
# ['baking needs', 'bread and cake', 'milk-cream'] -> ['vegetables']
# ['baking needs', 'sauces-gravy-pkle', 'bread and cake'] -> ['vegetables']
# ['baking needs', 'tissues-paper prd', 'bread and cake'] -> ['vegetables']
# ['baking needs', 'fruit', 'frozen foods'] -> ['milk-cream']
# ['baking needs', 'fruit', 'frozen foods'] -> ['vegetables']
# ['baking needs', 'frozen foods', 'milk-cream'] -> ['vegetables']
# ['baking needs', 'fruit', 'milk-cream'] -> ['vegetables']
# ['biscuits', 'bread and cake', 'frozen foods'] -> ['fruit']
# ['biscuits', 'bread and cake', 'juice-sat-cord-ms'] -> ['frozen foods']
# ['biscuits', 'bread and cake', 'margarine'] -> ['frozen foods']
# ['biscuits', 'bread and cake', 'frozen foods'] -> ['milk-cream']
# ['biscuits', 'bread and cake', 'party snack foods'] -> ['frozen foods']
# ['biscuits', 'bread and cake', 'frozen foods'] -> ['vegetables']
# ['biscuits', 'bread and cake', 'juice-sat-cord-ms'] -> ['fruit']
# ['biscuits', 'bread and cake', 'margarine'] -> ['fruit']
# ['fruit', 'biscuits', 'bread and cake'] -> ['milk-cream']
# ['biscuits', 'bread and cake', 'party snack foods'] -> ['fruit']
# ['fruit', 'biscuits', 'bread and cake'] -> ['vegetables']
# ['biscuits', 'bread and cake', 'party snack foods'] -> ['milk-cream']
# ['biscuits', 'bread and cake', 'milk-cream'] -> ['vegetables']
# ['biscuits', 'bread and cake', 'party snack foods'] -> ['vegetables']
# ['fruit', 'biscuits', 'frozen foods'] -> ['milk-cream']
# ['fruit', 'biscuits', 'frozen foods'] -> ['vegetables']
# ['fruit', 'biscuits', 'milk-cream'] -> ['vegetables']
# ['bread and cake', 'frozen foods', 'juice-sat-cord-ms'] -> ['fruit']
# ['fruit', 'bread and cake', 'frozen foods'] -> ['milk-cream']
# ['bread and cake', 'party snack foods', 'frozen foods'] -> ['fruit']
# ['tissues-paper prd', 'bread and cake', 'frozen foods'] -> ['fruit']
# ['fruit', 'bread and cake', 'frozen foods'] -> ['vegetables']
# ['bread and cake', 'frozen foods', 'juice-sat-cord-ms'] -> ['vegetables']
# ['bread and cake', 'frozen foods', 'margarine'] -> ['vegetables']
# ['bread and cake', 'frozen foods', 'milk-cream'] -> ['vegetables']
# ['bread and cake', 'party snack foods', 'frozen foods'] -> ['vegetables']
# ['sauces-gravy-pkle', 'bread and cake', 'frozen foods'] -> ['vegetables']
# ['tissues-paper prd', 'bread and cake', 'frozen foods'] -> ['vegetables']
# ['fruit', 'bread and cake', 'juice-sat-cord-ms'] -> ['milk-cream']
# ['fruit', 'bread and cake', 'juice-sat-cord-ms'] -> ['vegetables']
# ['fruit', 'bread and cake', 'margarine'] -> ['milk-cream']
# ['fruit', 'bread and cake', 'margarine'] -> ['vegetables']
# ['fruit', 'bread and cake', 'party snack foods'] -> ['milk-cream']
# ['fruit', 'tissues-paper prd', 'bread and cake'] -> ['milk-cream']
# ['fruit', 'bread and cake', 'milk-cream'] -> ['vegetables']
# ['fruit', 'bread and cake', 'party snack foods'] -> ['vegetables']
# ['fruit', 'sauces-gravy-pkle', 'bread and cake'] -> ['vegetables']
# ['fruit', 'tissues-paper prd', 'bread and cake'] -> ['vegetables']
# ['bread and cake', 'milk-cream', 'juice-sat-cord-ms'] -> ['vegetables']
# ['bread and cake', 'milk-cream', 'margarine'] -> ['vegetables']
# ['tissues-paper prd', 'bread and cake', 'milk-cream'] -> ['vegetables']
# ['fruit', 'frozen foods', 'milk-cream'] -> ['vegetables']
# ['baking needs', 'bread and cake', 'fruit', 'milk-cream'] -> ['vegetables']
# ['fruit', 'biscuits', 'frozen foods'] -> ['bread and cake', 'vegetables']

# %%
print('There are '+str(len(results))+' rules with a minimum support of '+str(mins)+
      ' and a minimum confidence of ' +str(minc))
# Out:
# There are 363 rules with a minimum support of 0.2 and a minimum confidence of 0.7

# %% [markdown]
# Of course, not all of them are informative enough. This level of interest is given by the lift. The interesting association rules are those with lifts far from 1. The *apriori* function can also take a minimum lift as an argument. For example, if we fix a minimum lift of $1.33$, we get the following reduced set of more interesting rules.

# %%
minl = 1.33

results_minlift = list(apriori(transactions,min_support=mins,min_confidence=minc,min_lift=minl))

# %%
for i in range(len(results_minlift)):
    print(list(results_minlift[i][2][0][0]),'->',list(results_minlift[i][2][0][1]))
# Out:
# ['margarine', 'party snack foods'] -> ['biscuits']
# ['baking needs', 'bread and cake', 'frozen foods'] -> ['biscuits']
# ['baking needs', 'bread and cake', 'party snack foods'] -> ['biscuits']
# ['baking needs', 'fruit', 'frozen foods'] -> ['biscuits']
# ['bread and cake', 'frozen foods', 'margarine'] -> ['biscuits']
# ['bread and cake', 'party snack foods', 'frozen foods'] -> ['biscuits']
# ['fruit', 'biscuits', 'frozen foods'] -> ['bread and cake', 'vegetables']

# %%
print('There are '+str(len(results_minlift))+' rules with a minimum support of '+str(mins)+
      ', a minimum confidence of ' +str(minc)+
      ' and a minimum lift of ' +str(minl))
# Out:
# There are 7 rules with a minimum support of 0.2, a minimum confidence of 0.7 and a minimum lift of 1.33
